# %%
import pandas as pd
import numpy as np

import pymysql                        # for getting data from a SQL database
from sqlalchemy import create_engine  # for establishing the connection and authentication

from getpass import getpass  # To get the password without showing the input

# %%
password = getpass()
#
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/EVsGermany'
engine = create_engine(connection_string)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
cars_df = pd.read_csv('cars_final.csv')
# Out:
# /var/folders/pf/nfj1603d1fjc2xkhkrlls95m0000gn/T/ipykernel_63353/2494030787.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   cars_df = pd.read_csv('cars_final.csv')

# %%
cars_df.head(10)
# Out:
#       brand commercial_name fuel_type  year      month
# 0  HONDA UK              JA    petrol  2015  Undefined
# 1  HONDA UK              JA    petrol  2015  Undefined
# 2  HONDA UK              JA    petrol  2015  Undefined
# 3  HONDA UK              JA    petrol  2015  Undefined
# 4  HONDA UK              JA    petrol  2015  Undefined
# 5  HONDA UK              JA    petrol  2015  Undefined
# 6   HYUNDAI         UNKNOWN    diesel  2015  Undefined
# 7   HYUNDAI         UNKNOWN    diesel  2015  Undefined
# 8   HYUNDAI         UNKNOWN    diesel  2015  Undefined
# 9   HYUNDAI         UNKNOWN    petrol  2015  Undefined

# %%
charging_df = pd.read_csv('charging_final.csv')

# %%
charging_df.head(10)
# Out:
#                          operator type_of_charging_equipment  \
# 0                         GGEW AG           Standard_charger
# 1                   Pfalzwerke AG              Super_charger
# 2             ENTEGA Energie GmbH           Standard_charger
# 3                Entega Plus GmbH           Standard_charger
# 4                Entega Plus GmbH           Standard_charger
# 5  Vogel Autohäuser GmbH & Co. KG           Standard_charger
# 6                Entega Plus GmbH              Super_charger
# 7                Entega Plus GmbH           Standard_charger
# 8                        ALDI SÜD           Standard_charger
# 9             ENTEGA Energie GmbH           Standard_charger
#
#    number_of_charging_points  connected_load      plug_types_1  p1_kw  \
# 0                          1             4.6  AC Socket Type 2    4.6
# 1                          2            75.0  AC Socket Type 2   22.0
# 2                          2            44.0  AC Socket Type 2   22.0
# ...

# %%
charging_df.to_sql('charging_infrastructure', engine, if_exists='replace', index=False)
# Out:
# 36254

# %%
cars_df.to_sql('cars_germany', engine, if_exists='replace', index=False)
# Out:
# 15048854
